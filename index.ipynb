# %%
! pip install requirements.txt
# Out:
# Looking in indexes: https://pypi.mirrors.ustc.edu.cn/simple/
# ERROR: Could not find a version that satisfies the requirement requirements.txt (from versions: none)
# ERROR: No matching distribution found for requirements.txt

# %% [markdown]
# # pandas常用操作
#
# 官方文档：https://www.pypandas.cn/docs/reference.html

# %% [markdown]
# ## 上下合并

# %%
import pandas as pd
import numpy as np
import os

# %%
data_merge1=pd.read_csv("./data/1.csv")
data_merge2=pd.read_csv("./data/2.csv")
data_merge1,data_merge2
# Out:
# (   1  2  3
#  0  a  a  w
#  1  b  b  s
#  2  c  c  d,
#     1  2  3
#  0  b  b  b
#  1  b  b  b
#  2  b  b  b)

# %%
# 直接合并
pd.concat([data_merge1, data_merge2])
# Out:
#    1  2  3
# 0  a  a  w
# 1  b  b  s
# 2  c  c  d
# 0  b  b  b
# 1  b  b  b
# 2  b  b  b

# %% [markdown]
# ## 左右合并

# %%
data_merge1=pd.read_csv("./data/3.csv")
data_merge2=pd.read_csv("./data/4.csv")
# Out:
#     1    3
# 0  张三   90
# 1  李四   80
# 2  王二  100

# %%
data_merge1#表1
# Out:
#     1  2
# 0  张三  a
# 1  李四  b
# 2  王二  c

# %%
data_merge2#表2
# Out:
#     1    3
# 0  张三   90
# 1  李四   80
# 2  王二  100

# %%
pd.merge(data_merge1,data_merge2,on="1")
# Out:
#     1  2    3
# 0  张三  a   90
# 1  李四  b   80
# 2  王二  c  100

# %% [markdown]
# ## 通过列表筛选

# %%
remove_ls=["张三","王二"]
df=pd.read_csv("./data/3.csv")
df
# Out:
#     1  2
# 0  张三  a
# 1  李四  b
# 2  王二  c

# %%
df[df['1'].isin(remove_ls)] #选出在列表中的数据
# Out:
#     1  2
# 0  张三  a
# 2  王二  c

# %%
df[~df['1'].isin(remove_ls)] #选出在不🙅‍列表中的数据
# Out:
#     1  2
# 1  李四  b

# %% [markdown]
# ## isin
#
# 返回bool值

# %%
df['1'].isin(remove_ls)
# Out:
# 0     True
# 1    False
# 2     True
# Name: 1, dtype: bool
